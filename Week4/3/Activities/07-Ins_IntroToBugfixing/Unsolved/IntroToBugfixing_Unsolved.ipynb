# %%
# Import dependencies
import pandas as pd

# %%
# Reference to CSV and reading CSV into Pandas DataFrame
csv_path = "Resources/flavors_of_cacao.csv"
chocolate_ratings_df = pd.read_csv(csv_path)
chocolate_ratings_df.head(10)
# Out:
#   Company (Maker-if known) Specific Bean Origin or Bar Name   REF  \
# 0                 A. Morin                      Agua Grande  1876
# 1                 A. Morin                            Kpime  1676
# 2                 A. Morin                           Atsane  1676
# 3                 A. Morin                            Akata  1680
# 4                 A. Morin                           Quilla  1704
# 5                 A. Morin                         Carenero  1315
# 6                 A. Morin                             Cuba  1315
# 7                 A. Morin                     Sur del Lago  1315
# 8                 A. Morin                   Puerto Cabello  1319
# 9                 A. Morin                          Pablino  1319
#
#    Review Date Cocoa Percent Company Location  Rating Bean Type  \
# 0         2016           63%           France    3.75
# 1         2015           70%           France    2.75
# 2         2015           70%           France    3.00
# ...

# %%
chocolate_ratings_df.columns
# Out:
# Index(['Company (Maker-if known)', 'Specific Bean Origin or Bar Name', 'REF',
#        'Review Date', 'Cocoa Percent', 'Company Location', 'Rating',
#        'Bean Type', 'Broad Bean Origin'],
#       dtype='object')

# %%
chocolate_ratings_df["Cocoa Percent"]
# Out:
# 0       63%
# 1       70%
# 2       70%
# 3       70%
# 4       70%
# 5       70%
# 6       70%
# 7       70%
# 8       70%
# 9       70%
# 10      70%
# 11      70%
# 12      70%
# 13      70%
# 14      70%
# 15      70%
# 16      70%
# 17      70%
# 18      70%
# 19      70%
# 20      63%
# 21      70%
# 22      63%
# 23      70%
# 24      70%
# 25      60%
# 26      80%
# 27      88%
# 28      72%
# 29      55%
#        ...
# 1765    70%
# 1766    60%
# 1767    70%
# 1768    70%
# 1769    85%
# 1770    85%
# 1771    70%
# 1772    78%
# 1773    78%
# 1774    65%
# 1775    68%
# 1776    66%
# 1777    72%
# 1778    80%
# 1779    72%
# 1780    65%
# 1781    70%
# 1782    70%
# 1783    62%
# 1784    75%
# 1785    75%
# 1786    90%
# 1787    70%
# 1788    68%
# 1789    58%
# 1790    70%
# 1791    65%
# 1792    65%
# 1793    62%
# 1794    65%
# Name: Cocoa Percent, Length: 1795, dtype: object

# %%
# Finding the average cocoa percent
# cocoa percent needs to be integer, it's currently a string
chocolate_ratings_df["Cocoa Percent"] = pd.to_numeric(chocolate_ratings_df["Cocoa Percent"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "63%"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-b66277df4c5c> in <module>
#       1 # Finding the average cocoa percent
#       2 # cocoa percent needs to be integer, it's currently a string
# ----> 3 chocolate_ratings_df["Cocoa Percent"] = pd.to_numeric(chocolate_ratings_df["Cocoa Percent"])
#
# ~\Anaconda3\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     133             coerce_numeric = False if errors in ('ignore', 'raise') else True
#     134             values = lib.maybe_convert_numeric(values, set(),
# ...

# %%
# turn to float, for those pesky decimal point percentages
chocolate_ratings_df["Cocoa Percent"] = chocolate_ratings_df["Cocoa Percent"].astype(float).map("{:,.2f}".format)
Cocoa_Percent
#now run the avg
